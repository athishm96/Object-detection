# %%
from imutils import paths
import argparse
import requests
import cv2
import os

# construct the argument parse and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-u", "--urls", required=True,
	help="path to file containing image URLs")
ap.add_argument("-o", "--output", required=True,
	help="path to output directory of images")
args = vars(ap.parse_args())

# grab the list of URLs from the input file, then initialize the
# total number of images downloaded thus far
rows = open(args["urls"]).read().strip().split("\n")
total = 0

# loop the URLs
for url in rows:
	try:
		# try to download the image
		r = requests.get(url, timeout=60)

		# save the image to disk
		p = os.path.sep.join([args["output"], "{}.jpg".format(
			str(total).zfill(8))])
		f = open(p, "wb")
		f.write(r.content)
		f.close()

		# update the counter
		print("[INFO] downloaded: {}".format(p))
		total += 1

	# handle if any exceptions are thrown during the download process
	except:
		print("[INFO] error downloading {}...skipping".format(p))

# loop over the image paths we just downloaded
for imagePath in paths.list_images(args["output"]):
	# initialize if the image should be deleted or not
	delete = False

	# try to load the image
	try:
		image = cv2.imread(imagePath)

		# if the image is `None` then we could not properly load it
		# from disk, so delete it
		if image is None:
			print("None")
			delete = True

	# if OpenCV cannot load the image then the image is likely
	# corrupt so we should delete it
	except:
		print("Except")
		delete = True

	# check to see if the image should be deleted
	if delete:
		print("[INFO] deleting {}".format(imagePath))
		os.remove(imagePath)
# Out:
# usage: ipykernel_launcher.py [-h] -u URLS -o OUTPUT
# ipykernel_launcher.py: error: the following arguments are required: -u/--urls, -o/--output
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Athish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from imutils import paths
import argparse
import requests
import cv2
import os

# construct the argument parse and parse the arguments


# grab the list of URLs from the input file, then initialize the
# total number of images downloaded thus far
rows = open("urls.txt").read().strip().split("\n")
total = 0

# loop the URLs
for url in rows:
	try:
		# try to download the image
		r = requests.get(url, timeout=60)

		# save the image to disk
		p = os.path.sep.join(["images/Toothpaste", "{}.jpg".format(
			str(total).zfill(8))])
		f = open(p, "wb")
		f.write(r.content)
		f.close()

		# update the counter
		print("[INFO] downloaded: {}".format(p))
		total += 1

	# handle if any exceptions are thrown during the download process
	except:
		print("[INFO] error downloading {}...skipping".format(p))

# loop over the image paths we just downloaded
for imagePath in paths.list_images(args["output"]):
	# initialize if the image should be deleted or not
	delete = False

	# try to load the image
	try:
		image = cv2.imread(imagePath)

		# if the image is `None` then we could not properly load it
		# from disk, so delete it
		if image is None:
			print("None")
			delete = True

	# if OpenCV cannot load the image then the image is likely
	# corrupt so we should delete it
	except:
		print("Except")
		delete = True

	# check to see if the image should be deleted
	if delete:
		print("[INFO] deleting {}".format(imagePath))
		os.remove(imagePath)
# Out:
# [INFO] downloaded: images/Toothpaste\00000000.jpg
# [INFO] downloaded: images/Toothpaste\00000001.jpg
# [INFO] downloaded: images/Toothpaste\00000002.jpg
# [INFO] downloaded: images/Toothpaste\00000003.jpg
# [INFO] downloaded: images/Toothpaste\00000054.jpg
# [INFO] downloaded: images/Toothpaste\00000055.jpg
# [INFO] downloaded: images/Toothpaste\00000056.jpg
# [INFO] downloaded: images/Toothpaste\00000057.jpg
# [INFO] downloaded: images/Toothpaste\00000058.jpg
# [INFO] downloaded: images/Toothpaste\00000059.jpg
# [INFO] downloaded: images/Toothpaste\00000060.jpg
# [INFO] downloaded: images/Toothpaste\00000061.jpg
# [INFO] downloaded: images/Toothpaste\00000062.jpg
# [INFO] downloaded: images/Toothpaste\00000063.jpg
# [INFO] downloaded: images/Toothpaste\00000064.jpg
# [INFO] downloaded: images/Toothpaste\00000065.jpg
# [INFO] downloaded: images/Toothpaste\00000066.jpg
# [INFO] downloaded: images/Toothpaste\00000067.jpg
# [INFO] downloaded: images/Toothpaste\00000068.jpg
# [INFO] downloaded: images/Toothpaste\00000069.jpg
# [INFO] downloaded: images/Toothpaste\00000070.jpg
# [INFO] downloaded: images/Toothpaste\00000071.jpg
# [INFO] downloaded: images/Toothpaste\00000072.jpg
# [INFO] downloaded: images/Toothpaste\00000073.jpg
# [INFO] downloaded: images/Toothpaste\00000074.jpg
# [INFO] downloaded: images/Toothpaste\00000075.jpg
# [INFO] downloaded: images/Toothpaste\00000076.jpg
# [INFO] downloaded: images/Toothpaste\00000077.jpg
# [INFO] downloaded: images/Toothpaste\00000078.jpg
# [INFO] downloaded: images/Toothpaste\00000079.jpg
# [INFO] downloaded: images/Toothpaste\00000080.jpg
# [INFO] downloaded: images/Toothpaste\00000081.jpg
# [INFO] downloaded: images/Toothpaste\00000082.jpg
# [INFO] downloaded: images/Toothpaste\00000083.jpg
# [INFO] downloaded: images/Toothpaste\00000084.jpg
# [INFO] downloaded: images/Toothpaste\00000085.jpg
# [INFO] downloaded: images/Toothpaste\00000086.jpg
# [INFO] downloaded: images/Toothpaste\00000087.jpg
# [INFO] downloaded: images/Toothpaste\00000088.jpg
# [INFO] downloaded: images/Toothpaste\00000089.jpg
# [INFO] downloaded: images/Toothpaste\00000090.jpg
# [INFO] downloaded: images/Toothpaste\00000091.jpg
# [INFO] downloaded: images/Toothpaste\00000092.jpg
# [INFO] downloaded: images/Toothpaste\00000093.jpg
# [INFO] downloaded: images/Toothpaste\00000094.jpg
# [INFO] downloaded: images/Toothpaste\00000095.jpg
# [INFO] downloaded: images/Toothpaste\00000096.jpg
# [INFO] downloaded: images/Toothpaste\00000097.jpg
# [INFO] downloaded: images/Toothpaste\00000098.jpg
# [INFO] downloaded: images/Toothpaste\00000099.jpg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-935a2003c569> in <module>()
#      35
#      36 # loop over the image paths we just downloaded
# ---> 37 for imagePath in paths.list_images(args["output"]):
#      38         # initialize if the image should be deleted or not
#      39         delete = False
#
# NameError: name 'args' is not defined
